# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/countries of the world.csv')

# %%
df.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
df.tail()
# Out:
#              Country                               Region  Population  \
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 222            5860                      419,9                         0,00
# 223          266000                        1,0                         0,42
# 224          527970                       40,6                         0,36
# 225          752614                       15,3                         0,00
# 226          390580                       31,3                         0,00
#
#     Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
df.shape
# Out:
# (227, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             227 non-null    object
#  1   Region                              227 non-null    object
#  2   Population                          227 non-null    int64
#  3   Area (sq. mi.)                      227 non-null    int64
#  4   Pop. Density (per sq. mi.)          227 non-null    object
#  5   Coastline (coast/area ratio)        227 non-null    object
#  6   Net migration                       224 non-null    object
#  7   Infant mortality (per 1000 births)  224 non-null    object
#  8   GDP ($ per capita)                  226 non-null    float64
#  9   Literacy (%)                        209 non-null    object
#  10  Phones (per 1000)                   223 non-null    object
# ...

# %%
df.describe()
# Out:
#          Population  Area (sq. mi.)  GDP ($ per capita)
# count  2.270000e+02    2.270000e+02          226.000000
# mean   2.874028e+07    5.982270e+05         9689.823009
# std    1.178913e+08    1.790282e+06        10049.138513
# min    7.026000e+03    2.000000e+00          500.000000
# 25%    4.376240e+05    4.647500e+03         1900.000000
# 50%    4.786994e+06    8.660000e+04         5550.000000
# 75%    1.749777e+07    4.418110e+05        15700.000000
# max    1.313974e+09    1.707520e+07        55100.000000

# %%
df.isna().sum()   #MISSING VALUES COUNT
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          3
# Infant mortality (per 1000 births)     3
# GDP ($ per capita)                     1
# Literacy (%)                          18
# Phones (per 1000)                      4
# Arable (%)                             2
# Crops (%)                              2
# Other (%)                              2
# Climate                               22
# Birthrate                              3
# Deathrate                              4
# Agriculture                           15
# Industry                              16
# Service                               15
# dtype: int64

# %%
#CLEANING MISSING VALUES
df.replace('', np.nan, inplace=True)
df.isna().sum()
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          3
# Infant mortality (per 1000 births)     3
# GDP ($ per capita)                     1
# Literacy (%)                          18
# Phones (per 1000)                      4
# Arable (%)                             2
# Crops (%)                              2
# Other (%)                              2
# Climate                               22
# Birthrate                              3
# Deathrate                              4
# Agriculture                           15
# Industry                              16
# Service                               15
# dtype: int64

# %%
#CHANGE DATATYPE TO DATAFRAME
#1)TO GET COLMS WITH OBJ DATATYP
# object_col=[]
# for i in df:
#   if (df[i].dtype=='object'):
#     object_col.append(i)

# print(object_col)

# %%
object_col=[]
for i in df:
  if df[i].dtype=='object':
    object_col.append(i)
    print(f'{i}|{df[i].nunique()}|{df[i].unique()}')
    print('----------------------------------------------------------')
# Out:
# Country|227|['Afghanistan ' 'Albania ' 'Algeria ' 'American Samoa ' 'Andorra '
#  'Angola ' 'Anguilla ' 'Antigua & Barbuda ' 'Argentina ' 'Armenia '
#  'Aruba ' 'Australia ' 'Austria ' 'Azerbaijan ' 'Bahamas, The ' 'Bahrain '
#  'Bangladesh ' 'Barbados ' 'Belarus ' 'Belgium ' 'Belize ' 'Benin '
#  'Bermuda ' 'Bhutan ' 'Bolivia ' 'Bosnia & Herzegovina ' 'Botswana '
#  'Brazil ' 'British Virgin Is. ' 'Brunei ' 'Bulgaria ' 'Burkina Faso '
#  'Burma ' 'Burundi ' 'Cambodia ' 'Cameroon ' 'Canada ' 'Cape Verde '
#  'Cayman Islands ' 'Central African Rep. ' 'Chad ' 'Chile ' 'China '
#  'Colombia ' 'Comoros ' 'Congo, Dem. Rep. ' 'Congo, Repub. of the '
#  'Cook Islands ' 'Costa Rica ' "Cote d'Ivoire " 'Croatia ' 'Cuba '
#  'Cyprus ' 'Czech Republic ' 'Denmark ' 'Djibouti ' 'Dominica '
#  'Dominican Republic ' 'East Timor ' 'Ecuador ' 'Egypt ' 'El Salvador '
#  'Equatorial Guinea ' 'Eritrea ' 'Estonia ' 'Ethiopia ' 'Faroe Islands '
# ...

# %%
df['Country'].value_counts()
df['Country']=df['Country'].str.strip(' ')

# %%
df['Region'].value_counts()
df['Region']=df['Region'].str.strip(' ')
df['Region'].dtype
# Out:
# dtype('O')

# %%
# df['Pop. Density (per sq. mi.)']=df['Pop. Density (per sq. mi.)'].replace(',','.',regex=True).astype('float')
# df['Pop. Density (per sq. mi.)']

# %%
# df['Coastline (coast/area ratio)']=df['Coastline (coast/area ratio)'].replace(',','.',regex=True).astype('float')
# df['Coastline (coast/area ratio)']

# %%
# df[['Infant mortality (per 1000 births)','Literacy (%)']]=df[['Infant mortality (per 1000 births)','Literacy (%)']].replace(',','.',regex=True).astype('float')
# df[['Infant mortality (per 1000 births)','Literacy (%)']]

# %%
df[['Pop. Density (per sq. mi.)','Coastline (coast/area ratio)','Infant mortality (per 1000 births)','Literacy (%)','Phones (per 1000)','Arable (%)','Crops (%)','Other (%)','Climate','Birthrate','Deathrate','Agriculture','Industry','Service','Net migration']]=df[['Pop. Density (per sq. mi.)','Coastline (coast/area ratio)','Infant mortality (per 1000 births)','Literacy (%)','Phones (per 1000)','Arable (%)','Crops (%)','Other (%)','Climate','Birthrate','Deathrate','Agriculture','Industry','Service','Net migration']].replace(',','.',regex=True).astype('float')
df[['Pop. Density (per sq. mi.)','Coastline (coast/area ratio)','Infant mortality (per 1000 births)','Literacy (%)','Phones (per 1000)','Arable (%)','Crops (%)','Other (%)','Climate','Birthrate','Deathrate','Agriculture','Industry','Service','Net migration']]
# Out:
#      Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0                          48.0                          0.00
# 1                         124.6                          1.26
# 2                          13.8                          0.04
# 3                         290.4                         58.29
# 4                         152.1                          0.00
# ..                          ...                           ...
# 222                       419.9                          0.00
# 223                         1.0                          0.42
# 224                        40.6                          0.36
# 225                        15.3                          0.00
# 226                        31.3                          0.00
#
#      Infant mortality (per 1000 births)  Literacy (%)  Phones (per 1000)  \
# 0                                163.07          36.0                3.2
# ...

# %%
object_col=[]
for i in df:
  if df[i].dtype=='object':
    object_col.append(i)
    print(f'{i}|{df[i].nunique()}|{df[i].unique()}')
    print('----------------------------------------------------------')
# Out:
# Country|227|['Afghanistan' 'Albania' 'Algeria' 'American Samoa' 'Andorra' 'Angola'
#  'Anguilla' 'Antigua & Barbuda' 'Argentina' 'Armenia' 'Aruba' 'Australia'
#  'Austria' 'Azerbaijan' 'Bahamas, The' 'Bahrain' 'Bangladesh' 'Barbados'
#  'Belarus' 'Belgium' 'Belize' 'Benin' 'Bermuda' 'Bhutan' 'Bolivia'
#  'Bosnia & Herzegovina' 'Botswana' 'Brazil' 'British Virgin Is.' 'Brunei'
#  'Bulgaria' 'Burkina Faso' 'Burma' 'Burundi' 'Cambodia' 'Cameroon'
#  'Canada' 'Cape Verde' 'Cayman Islands' 'Central African Rep.' 'Chad'
#  'Chile' 'China' 'Colombia' 'Comoros' 'Congo, Dem. Rep.'
#  'Congo, Repub. of the' 'Cook Islands' 'Costa Rica' "Cote d'Ivoire"
#  'Croatia' 'Cuba' 'Cyprus' 'Czech Republic' 'Denmark' 'Djibouti'
#  'Dominica' 'Dominican Republic' 'East Timor' 'Ecuador' 'Egypt'
#  'El Salvador' 'Equatorial Guinea' 'Eritrea' 'Estonia' 'Ethiopia'
#  'Faroe Islands' 'Fiji' 'Finland' 'France' 'French Guiana'
#  'French Polynesia' 'Gabon' 'Gambia, The' 'Gaza Strip' 'Georgia' 'Germany'
# ...

# %% [markdown]
# -- 1)Add a column for GDP per capita:
#
#  ALTER TABLE `countries of the world`
#  ADD COLUMN GDP_per_Capita FLOAT;
#
# UPDATE `countries of the world`
# SET GDP_per_Capita = `GDP ($ per capita)` / Population;
#
# select Country,`GDP ($ per capita)` from `countries of the world`;
#
# -- 2)Create a categorical column for population density:
#
# ALTER TABLE `countries of the world`
# ADD COLUMN Density_Category VARCHAR(50);
#
# UPDATE `countries of the world`
# SET Density_Category = CASE
#     WHEN `Pop. Density (per sq. mi.)` < 50 THEN 'Low'
#     WHEN `Pop. Density (per sq. mi.)` BETWEEN 50 AND 200 THEN 'Medium'
#     ELSE 'High'
# END;
#
# UPDATE countries of the world SET Density_Category = CASE WHEN Pop. Density (per sq. mi.) < 50 THEN
# 'Low' WHEN Pop. Density (per sq. mi.) BETWEEN 50 AND 200 THEN 'Medium' ELSE 'High' END;
#
# df[Density_Category]=np.where(df['Pop. Density (per sq. mi.)']<=50,Low) this can also be used in true false condition
#
#
# -- 3)Extract the continent from the region:
#
# ALTER TABLE `countries of the world`
# ADD COLUMN Continent VARCHAR(50);
#
# UPDATE `countries of the world`
# SET Continent = CASE
#     WHEN Region LIKE '%Asia%' or Region LIKE '%Near East%' THEN 'Asia'
#     WHEN Region LIKE '%Africa%' THEN 'Africa'
#     WHEN Region LIKE '%Europe%' THEN 'Europe'
#     WHEN Region LIKE '%Americas%' THEN 'North America'
#     WHEN Region LIKE '%Latin Amer. & Carib%' THEN 'South America'
#     WHEN Region LIKE '%Oceania%' THEN 'Oceania'
#     ELSE 'Other'
# END;
#
#
# -- 4) Climate
#
# ALTER TABLE `countries of the world`
# ADD COLUMN Climate_category VARCHAR(50);
#
# UPDATE `countries of the world`
# SET
#     Climate_category = CASE
#         WHEN Climate = 1 THEN 'Tropical'
#         WHEN Climate = 2 THEN 'Arid'
#         WHEN Climate = 3 THEN 'Temperate'
#         WHEN Climate = 4 THEN 'Cold'
#         ELSE 'Unknown'
#     END;-- Handle any other values not explicitly mapped

# %%
# Creating a new column 'Density_category' based on a condition
df['Density_category'] = 'High'  # Initialize the 'Density_category' column with 'High' as the default value

# # Using DataFrame.loc[] to set values based on the condition
df.loc[df['Pop. Density (per sq. mi.)'] < 50, 'Density_category'] = 'Low'
df.loc[(df['Pop. Density (per sq. mi.)'] >=50) & (df['Pop. Density (per sq. mi.)'] <=200), 'Density_category'] = 'Medium'

# # Displaying the modified dataframe
print(df['Density_category'])
# Out:
# 0         Low
# 1      Medium
# 2         Low
# 3        High
# 4      Medium
#         ...
# 222      High
# 223       Low
# 224       Low
# 225       Low
# 226       Low
# Name: Density_category, Length: 227, dtype: object

# %%
df['GDP_per_Capita'] = df['GDP ($ per capita)']/ df['Population']
df['GDP_per_Capita']
# Out:
# 0      0.000023
# 1      0.001256
# 2      0.000182
# 3      0.138423
# 4      0.266850
#          ...
# 222    0.000325
# 223         NaN
# 224    0.000037
# 225    0.000070
# 226    0.000155
# Name: GDP_per_Capita, Length: 227, dtype: float64

# %%
df['Climate_category']='Unknown'
df.loc[df['Climate'] == 1, 'Climate_category'] = 'Tropical'
df.loc[df['Climate'] == 2, 'Climate_category'] = 'Arid'
df.loc[df['Climate'] == 3, 'Climate_category'] = 'Temperate'
df.loc[df['Climate'] == 4, 'Climate_category'] = 'Cold'
df['Climate_category']
# Out:
# 0       Tropical
# 1      Temperate
# 2       Tropical
# 3           Arid
# 4      Temperate
#          ...
# 222    Temperate
# 223     Tropical
# 224     Tropical
# 225         Arid
# 226         Arid
# Name: Climate_category, Length: 227, dtype: object

# %%
df['Continent']='Others'
df.loc[(df['Region'] == 'ASIA (EX. NEAR EAST)') | (df['Region'] == 'NEAR EAST'), 'Continent'] = 'Asia'
df.loc[(df['Region']=='NORTHERN AFRICA')|(df['Region']=='SUB-SAHARAN AFRICA'),'Continent']='Africa'
df.loc[(df['Region']=='WESTERN EUROPE')|(df['Region']=='EASTERN EUROPE'),'Continent']='Europe'
df.loc[df['Region']=='NORTHERN AMERICA','Continent']='North America'
df.loc[df['Region']=='LATIN AMER. & CARIB','Continent']='South America'
df.loc[df['Region']=='OCEANIA','Continent']='Oceania'
df['Continent'].value_counts()
# Out:
# Continent
# Africa           57
# South America    45
# Asia             44
# Europe           40
# Oceania          21
# Others           15
# North America     5
# Name: count, dtype: int64

# %% [markdown]
# **EDA**

# %%
df.head()
# Out:
#           Country                Region  Population  Area (sq. mi.)  \
# 0     Afghanistan  ASIA (EX. NEAR EAST)    31056997          647500
# 1         Albania        EASTERN EUROPE     3581655           28748
# 2         Algeria       NORTHERN AFRICA    32930091         2381740
# 3  American Samoa               OCEANIA       57794             199
# 4         Andorra        WESTERN EUROPE       71201             468
#
#    Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  Net migration  \
# 0                        48.0                          0.00          23.06
# 1                       124.6                          1.26          -4.93
# 2                        13.8                          0.04          -0.39
# 3                       290.4                         58.29         -20.71
# 4                       152.1                          0.00           6.60
#
#    Infant mortality (per 1000 births)  GDP ($ per capita)  Literacy (%)  ...  \
# ...

# %% [markdown]
# The .idxmax() function in pandas is used to return the index (or label) of the first occurrence of the maximum value along an axis. When used on a DataFrame column, it returns the index of the row where the maximum value is found.

# %%
#1.Which countries have the highest and lowest populations?

print(df.loc[df['Population'].idxmax(), ['Country', 'Population']])
print()
print(df.loc[df['Population'].idxmin(), ['Country', 'Population']])
# Out:
# Country            China
# Population    1313973713
# Name: 42, dtype: object
#
# Country       St Pierre & Miquelon
# Population                    7026
# Name: 174, dtype: object

# %%
#2.What are the largest and smallest countries by land area?
print(df.loc[df['Area (sq. mi.)'].idxmax(),['Country','Area (sq. mi.)']])
print()
print(df.loc[df['Area (sq. mi.)'].idxmin(),['Country','Area (sq. mi.)']])
# Out:
# Country             Russia
# Area (sq. mi.)    17075200
# Name: 169, dtype: object
#
# Country           Monaco
# Area (sq. mi.)         2
# Name: 138, dtype: object

# %%
#3.What are the top 10 countries by GDP and which country has the maximum GDP growth ?
df.nlargest(10, 'GDP ($ per capita)')[['Country', 'GDP ($ per capita)']]
# Out:
#             Country  GDP ($ per capita)
# 121      Luxembourg             55100.0
# 154          Norway             37800.0
# 214   United States             37800.0
# 22          Bermuda             36000.0
# 38   Cayman Islands             35000.0
# 177      San Marino             34600.0
# 196     Switzerland             32700.0
# 54          Denmark             31100.0
# 93          Iceland             30900.0
# 12          Austria             30000.0

# %%
#4.What is the average population density across all countries?
df['Pop. Density (per sq. mi.)'].mean()
# Out:
# 379.0471365638766

# %%
#5.Which country is having the highest infant mortality rate?
df.loc[df['Infant mortality (per 1000 births)'].idxmax(), ['Country','Infant mortality (per 1000 births)']]
# Out:
# Country                               Angola
# Infant mortality (per 1000 births)    191.19
# Name: 5, dtype: object

# %%
#6.What is the average literacy rate by region?
df.groupby('Region')['Literacy (%)'].mean().sort_values(ascending=False)
# Out:
# Region
# BALTICS                 99.733333
# C.W. OF IND. STATES     98.725000
# WESTERN EUROPE          98.391304
# NORTHERN AMERICA        97.750000
# EASTERN EUROPE          97.088889
# LATIN AMER. & CARIB     90.654545
# OCEANIA                 88.835294
# ASIA (EX. NEAR EAST)    79.553571
# NEAR EAST               79.521429
# NORTHERN AFRICA         67.240000
# SUB-SAHARAN AFRICA      62.510000
# Name: Literacy (%), dtype: float64

# %%
#7.Which country has the lowest rates of mobile phone usage?
df.loc[df['Phones (per 1000)'].idxmin(),['Country','Phones (per 1000)']]
# Out:
# Country              Congo, Dem. Rep.
# Phones (per 1000)                 0.2
# Name: 45, dtype: object

# %%
#8.What is the birth and Death rate for each Continents
df.groupby('Continent')[['Birthrate', 'Deathrate']].mean()
# Out:
#                Birthrate  Deathrate
# Continent
# Africa         34.684107  14.235536
# Asia           22.566591   6.608864
# Europe         10.502051   9.616923
# North America  13.154000   7.694000
# Oceania        22.108000   5.810526
# Others         16.153333  10.799333
# South America  19.081111   6.376000

# %%
#9.Literacy rate varies across different Continents?
df.groupby('Continent')['Literacy (%)'].mean()
# Out:
# Continent
# Africa           62.940000
# Asia             79.542857
# Europe           98.025000
# North America    97.750000
# Oceania          88.835294
# Others           98.926667
# South America    90.654545
# Name: Literacy (%), dtype: float64

# %%
#10.How many countries are included in the dataset?
df['Country'].nunique()
# Out:
# 227

# %%
# 11.Total Population by Region
df.groupby('Region')['Population'].sum()
# Out:
# Region
# ASIA (EX. NEAR EAST)    3687982236
# BALTICS                    7184974
# C.W. OF IND. STATES      280081548
# EASTERN EUROPE           119914717
# LATIN AMER. & CARIB      561824599
# NEAR EAST                195068377
# NORTHERN AFRICA          161407133
# NORTHERN AMERICA         331672307
# OCEANIA                   33131662
# SUB-SAHARAN AFRICA       749437000
# WESTERN EUROPE           396339998
# Name: Population, dtype: int64

# %%
#12.Population Density Analysis
df['Population Density']= df['Population'] / df['Area (sq. mi.)']
df.nlargest(10, 'Population Density')[['Country', 'Population Density']]
# Out:
#         Country  Population Density
# 138      Monaco        16271.500000
# 122       Macau        16183.035714
# 184   Singapore         6482.178932
# 91    Hong Kong         6355.706960
# 78    Gibraltar         3989.714286
# 74   Gaza Strip         3968.769444
# 129       Malta         1266.500000
# 22      Bermuda         1241.000000
# 127    Maldives         1196.693333
# 15      Bahrain         1050.503759

# %%
#13. When considering the coastline, find the countries with the LONGEST coastlines.
df.loc[df['Coastline (coast/area ratio)'].idxmax(),['Country','Coastline (coast/area ratio)']]
# Out:
# Country                         Micronesia, Fed. St.
# Coastline (coast/area ratio)                  870.66
# Name: 136, dtype: object

# %%
#14. Find the countries with the most and least migrants.
print(df.loc[df['Net migration'].idxmax(),['Country','Net migration']])
print()
print(df.loc[df['Net migration'].idxmin(),['Country','Net migration']])
# Out:
# Country          Afghanistan
# Net migration          23.06
# Name: 0, dtype: object
#
# Country          Micronesia, Fed. St.
# Net migration                  -20.99
# Name: 136, dtype: object

# %%
#15. Find the continent with the most and least migrants.
continent_migration_sum=df.groupby('Continent')['Net migration'].sum()
print(continent_migration_sum)
print()
print('Continent with Most Migrants:',continent_migration_sum.idxmax(), continent_migration_sum.max())
print()
print('Continent with Least Migrants:',continent_migration_sum.idxmin(), continent_migration_sum.max())
# Out:
# Continent
# Africa          -19.25
# Asia             80.83
# Europe           85.23
# North America    -1.37
# Oceania         -39.15
# Others          -30.50
# South America   -67.25
# Name: Net migration, dtype: float64
#
# Continent with Most Migrants: Europe 85.23
#
# Continent with Least Migrants: South America 85.23

# %%
#16) Average GDP per Capita by Continent
df.groupby('Continent')['GDP_per_Capita'].mean().sort_values(ascending=False)
# Out:
# Continent
# North America    0.377057
# Europe           0.132497
# Oceania          0.097634
# South America    0.096716
# Africa           0.008985
# Asia             0.004942
# Others           0.001489
# Name: GDP_per_Capita, dtype: float64

# %%
#17) Highest GDP per Capita in Each Continent
df.loc[df.groupby('Continent')['GDP_per_Capita'].idxmax(),['Continent', 'Country', 'GDP_per_Capita']]
# Out:
#          Continent               Country  GDP_per_Capita
# 171         Africa          Saint Helena        0.333244
# 29            Asia                Brunei        0.049019
# 177         Europe            San Marino        1.182866
# 174  North America  St Pierre & Miquelon        0.982067
# 157        Oceania                 Palau        0.437339
# 64          Others               Estonia        0.009288
# 38   South America        Cayman Islands        0.770314

# %%
#18)Distribution of Density Categories
df['Density_category'].value_counts()
# Out:
# Density_category
# Medium    92
# Low       82
# High      53
# Name: count, dtype: int64

# %%
#climate
df.groupby(['Continent', 'Climate_category']).size().reset_index(name='Number_of_Countries')
# Out:
#         Continent Climate_category  Number_of_Countries
# 0          Africa             Arid                   33
# 1          Africa        Temperate                    4
# 2          Africa         Tropical                   10
# 3          Africa          Unknown                   10
# 4            Asia             Arid                   18
# 5            Asia        Temperate                    8
# 6            Asia         Tropical                   14
# 7            Asia          Unknown                    4
# 8          Europe             Cold                    3
# 9          Europe        Temperate                   27
# 10         Europe          Unknown                   10
# 11  North America             Arid                    1
# 12  North America        Temperate                    1
# 13  North America         Tropical                    1
# 14  North America          Unknown                    2
# 15        Oceania             Arid                   19
# ...
